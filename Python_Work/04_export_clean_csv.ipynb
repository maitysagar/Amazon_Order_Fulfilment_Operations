# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KIIT\\OneDrive\\Desktop\\Amazon_Order_Fulfilment_Operations\\Python_Work'

# %%
df = pd.read_csv("../Working_Files/amazon_orders_clean.csv")

# %%
df.shape
# Out:
# (79831, 19)

# %%
df.isna().sum()
# Out:
# index                     0
# order_id                  0
# date                      0
# status                    0
# fulfilment                0
# sales_channel             0
# ship-service-level        0
# category                  0
# size                      0
# courier_status            0
# qty                       0
# currency               4752
# amount                 4752
# ship-city                20
# ship-state               20
# ship-postal-code         20
# ship-country             20
# b2b                       0
# fulfilled-by          53258
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
export_path = "../Final_Output"

os.makedirs(export_path, exist_ok=True)

# %%
final_file = f"{export_path}/amazon_orders_final_clean.csv"

df.to_csv(final_file, index=False)

# %%
os.listdir(export_path)
# Out:
# ['amazon_orders_final_clean.csv']

# %%
# ### Final Dataset Export
# - Source: Amazon Order Fulfilment Raw Data
# - Cleaning: 01_load_and_clean_data.ipynb
# - Validation: 02_data_validation.ipynb
# - Analysis: 03_eda_analysis.ipynb
# - Output: amazon_orders_final_clean.csv
